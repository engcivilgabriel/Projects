# %% [markdown]
# <a href="https://colab.research.google.com/github/engcivilgabriel/Projects/blob/master/Doen%C3%A7as_Cardiovasculares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img width="15%" src="https://github.com/engcivilgabriel/Projects/blob/master/Logo.png?raw=true"></center>
#
# # **Prevenção de Doenças Cardiovasculares com Data Science**
#
# <center><img width="90%" src="https://cdn.pixabay.com/photo/2018/08/22/19/27/nurse-3624461_960_720.jpg"></center>
#
# Segundo o texto disponibilizado no site da [OPAS/OMS Brasil](https://www.paho.org/bra/index.php?option=com_content&view=article&id=5253:doencas-cardiovasculares&Itemid=1096), **as doenças cardiovasculares são a principal causa de morte no mundo:** mais pessoas morrem anualmente por essas enfermidades do que por qualquer outra causa. Esclarescendo, as doenças cardiovasculares são um grupo de doenças do coração e dos vasos sanguíneos e incluem:
#
# * Doença coronariana – doença dos vasos sanguíneos que irrigam o músculo cardíaco;
# * Doença cerebrovascular – doença dos vasos sanguíneos que irrigam o cérebro;
# * Doença arterial periférica – doença dos vasos sanguíneos que irrigam os membros superiores e inferiores;
# * Doença cardíaca reumática – danos no músculo do coração e válvulas cardíacas devido à febre reumática, causada por bactérias estreptocócicas;
# * Cardiopatia congênita – malformações na estrutura do coração existentes desde o momento do nascimento;
# * Trombose venosa profunda e embolia pulmonar – coágulos sanguíneos nas veias das pernas, que podem se desalojar e se mover para o coração e pulmões.
#
# Contudo, é interessante perceber que a maioria destas doenças cardiovasculares pode ser prevenida por meio da abordagem de fatores comportamentais de risco – como o uso de tabaco, dietas não saudáveis e obesidade, falta de atividade física e uso nocivo do álcool –, utilizando estratégias para a população em geral.
#
# Mas, como sabemos que só palavras não bastam, é válido termos consciência de que existem hoje várias pesquisas na área de *Machine Learning* visando a construções de modelos preditivos que ajudem os médicos a descobrirem doenças cardiovasculares em seus pacientes.
#
# Estudos publicados na revista *Nature Biomedical Engineering* mostram que algoritmos de *Deep Learning* foram capazes de antecipar doenças cardíacas em até 5 anos.
#
# Definitivamente, o uso de Inteligência Artificial tem impactado profundamente a área da saúde, e tem proporcionado aos profissionais médicos insumos de inteligência cada vez mais precisos.
#
# **Então, vamos nos aprofundar neste tema? O que será que os dados têm a nos dizer?**

# %% [markdown]
# ## **Obtenção dos Dados**
#
# O conjunto principal de dados usado neste projeto foi coletado da ***Cleveland Clinic Foundation*** e se encontra disponível no [Repositório UCI *Machine Learning*](https://archive.ics.uci.edu/ml/datasets/heart+Disease). Ressalta-se que os nomes, identidade e documentos pessoais dos pacientes foram removidos completamente do banco de dados.
#
# O *dataset* processado contém dados de 303 pessoas e 76 atributos. Entretanto, os principais artigos e estudos publicados optaram por usar apenas 14 atributos, considerados de maior relevância. Da mesma maneira, este projeto de *Data Science* usará essas mesmas 14 variáveis principais.
#
# * O arquivo `csv` com os dados de 303 pessoas e 14 atributos pode ser baixado [neste link](https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/heart-disease-uci.csv).
#
# * O arquivo contendo todos os detalhes e documentação do *dataset* usado neste projeto se encontra [neste link](https://github.com/carlosfab/curso_data_science_na_pratica/blob/master/modulo_03/heart-disease.names).
#
# * Há ainda um *dataset* secundário que será utilizado para ver a evolução no número de mortes por doenças cardiovasculares no Brasil (entre os anos de 2004-2017). Esses dados foram disponibilizados pela [Sociedade Brasileira de Cardiologia](http://www.cardiometro.com.br/anteriores.asp), e podem ser baixados [neste link](https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/mortes_doencas_cardiovasculares.csv).

# %% [markdown]
# ### Informações sobre os atributos:
#
#
# * `age` - idade em anos
# * `sex` - sexo do paciente
#   * 0: mulher
#   * 1: homem
# * `cp` - tipo da dor torácica
#   * 1: angina típica
#   * 2: angina atípica
#   * 3: dor não cardíaca
#   * 4: assintomática
# * `trestbps` - pressão arterial em repouso
# * `chol` - colesterol sérico (*mg/dl*)
# * `fbs` - açucar no sangue em jejum > 120*mg/dl*
#   * 0: `False`
#   * 1: `True`
# * `restecg` - resultado do eletrocardiografia de repouso
#   * 0: normal
#   * 1: anormalidades de ST-T  (inversão da onda T e elevação ou depressão de > 0.05*mV*)
#   * 2: hipertrofia ventricular esquerda provável ou definitiva (pelos critérios de Romhilt-Estes)
# * `thalach` - frequência cardíaca máxima atingida
# * `exang` - angina induzida pelo exercício
#   * 0: não
#   * 1: sim
# * `oldpeak` - depressão do segmento ST induzida pelo exercício em relação ao repouso
# * `slope` - inclinação do segmento ST no pico do exercício
# * `ca` - número de vasos principais colorido por fluoroscopia
# * `thal` - *thallium stress test*
#   * 3: normal
#   * 6: defeito fixo
#   * 7: defeito reversível
# * `num` - diagnóstico de doença cardíaca (diagnóstico angiográfico)
#   * 0: não há doença cardíaca ( < 50% de estreitamento do diâmetro)
#   * 1,2,3,4: há doença cardíaca ( > 50% de estreitamento do diâmetro)

# %% [markdown]
# ### Importar os Dados
#
# Em uma etapa inicial, importaremos os dois *datasets* mencionados no início do *notebook*:
#
# * Um contendo os dados relacionados às doenças cardiovasculares (303 pessoas e 14 atributos); e
# * Um contendo os dados da mortalidade no Brasil por doenças cardiovasculares.

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# url dos datasets
dataset_uci = "https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/heart-disease-uci.csv"
dataset_brasil = "https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/mortes_doencas_cardiovasculares.csv"

# importar dataset da UCI
df = pd.read_csv(dataset_uci)

# importar dataset dos indíces do Brasil
df_brasil = pd.read_csv(dataset_brasil)

# %% [markdown]
# Olhando acima as informações sobre os atributos, percebemos que nossa variável alvo (`num`) possui cinco valores possíveis: \[0, 1, 2, 3, 4\].
#
# No entanto, seguindo a maioria das pesquisas que utilizaram esse *dataset*, iremos considerar apenas duas situações possíveis:
#
# * **0** - não há doença cardíaca
# * **1** - há doença cardíaca
#
# Então, iremos igualar a 1 os valores compreendidos entre 1-4.

# %%
# variável alvo antes
df.num.value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %%
# converter valores >= 1 em 1
df.loc[df.num != 0, 'num'] = 1

# %%
# variável alvo depois
df.num.value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %% [markdown]
# ## **Análise Exploratória**

# %% [markdown]
# ###dataset_uci:
#
# Vamos começar a exploração dos dados definindo o seu volume de informações:

# %%
#tamanho do dataframe
print("Quantidade de linhas: ", df.shape[0])
print("Quantidade de colunas: ", df.shape[1])
# Out:
# Quantidade de linhas:  303
# Quantidade de colunas:  14

# %% [markdown]
# Sabendo que estamos lidando com um *dataframe* razoavelmente extenso, vamos agora descreve-lo estatisticamente:

# %%
#Descrição estatística do dataframe
df.describe()
# Out:
#               age         sex          cp  ...          ca        thal         num
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  ...    0.663366    4.722772    0.458746
# std      9.038662    0.467299    0.960126  ...    0.934375    1.938383    0.499120
# min     29.000000    0.000000    1.000000  ...    0.000000    3.000000    0.000000
# 25%     48.000000    0.000000    3.000000  ...    0.000000    3.000000    0.000000
# 50%     56.000000    1.000000    3.000000  ...    0.000000    3.000000    0.000000
# 75%     61.000000    1.000000    4.000000  ...    1.000000    7.000000    1.000000
# max     77.000000    1.000000    4.000000  ...    3.000000    7.000000    1.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# Sabemos que, apesar de todas as informações estarem expressas por valores numericos, nem todas podem ser qualificadas e analisadas como tal. Consequentemente, buscando prever com quais tipos de variáveis estamos lidando, definiremos a seguir quais seus respectivos tipos:

# %%
#Tipos das variaveis
df.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# num           int64
# dtype: object

# %% [markdown]
# Bem, agora podemos sem receios, ver qual a cara do nosso *dataframe*. Como já sabemos que há muitas informações presentes, vamos apenas visualizar as 5 primeiras entradas:

# %%
#Visualização das 5 primeiras entradas
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  ...  exang  oldpeak  slope   ca  thal  num
# 0  63.0  1.0  1.0     145.0  233.0  1.0  ...    0.0      2.3    3.0  0.0   6.0    0
# 1  67.0  1.0  4.0     160.0  286.0  0.0  ...    1.0      1.5    2.0  3.0   3.0    1
# 2  67.0  1.0  4.0     120.0  229.0  0.0  ...    1.0      2.6    2.0  2.0   7.0    1
# 3  37.0  1.0  3.0     130.0  250.0  0.0  ...    0.0      3.5    3.0  0.0   3.0    0
# 4  41.0  0.0  2.0     130.0  204.0  0.0  ...    0.0      1.4    1.0  0.0   3.0    0
#
# [5 rows x 14 columns]

# %% [markdown]
# Ótimo, tudo parece em ordem! Podemos, finalmente, começar a extrair algumas informações relevantes deste *dataframe*, vamos lá?

# %% [markdown]
# ####Q1. Quantas pessoas tem doenças cardíacas e quantas não?

# %%
#Definição da quantidade de pessoas com doenças cardíacas
print("Quantidade de pessoas com doenças cardíacas: ", (df.num == 1).sum())
print("Quantidade de pessoas sem doenças cardíacas: ", (df.num == 0).sum())
# Out:
# Quantidade de pessoas com doenças cardíacas:  139
# Quantidade de pessoas sem doenças cardíacas:  164

# %% [markdown]
# ####Q2. Destes resultados, qual a divisão entre gêneros presente?

# %%
#condicoes - homem com doença cardíaca = 2
#condicoes - mulher com doença cardíaca = 1
#condicoes - homem sem doença cardíaca = 1
#condicoes - mulher sem doença cardíaca = 0

#Passo 1
cond1 = df.num == 1
cond2 = df.sex == 1
cond_df = pd.concat([cond1,cond2],axis=1)

#Passo 2
df['condicoes'] = cond_df.sum(axis=1)

#Passo 3
print("Quantidade de homens com doenças cardíacas: ",(df.condicoes == 2).sum())
print("Quantidade de mulheres com doenças cardíacas: ",(df.num == 1).sum()-(df.condicoes == 2).sum())
print("Quantidade de homens sem doenças cardíacas: ", (df.num == 0).sum()-(df.condicoes == 0).sum())
print("Quantidade de mulheres sem doenças cardíacas: ", (df.condicoes == 0).sum())
# Out:
# Quantidade de homens com doenças cardíacas:  114
# Quantidade de mulheres com doenças cardíacas:  25
# Quantidade de homens sem doenças cardíacas:  92
# Quantidade de mulheres sem doenças cardíacas:  72

# %% [markdown]
# Como podemos ver na seguinte representação gráfica:

# %%
#Plotar um gráfico de barras relacionando e quantificando gênero e doenças cardíacas
import numpy as np
import seaborn as sns

x = ['hcdc', 'mcdc', 'hsdc', 'msdc']
y = [114, 25, 92, 72]

sns.axes_style('dark')
sns.set_style('white')

b = sns.barplot(x,y,color='blue')

for p in b.patches:
    b.annotate(
        s='{:.1f}'.format(p.get_height()),
        xy=(p.get_x()+p.get_width()/2.,p.get_height()),
        ha='center',va='center',
        xytext=(0,10),
        textcoords='offset points'
)

b.set_yticks([])
sns.despine(ax=b, left=True, bottom=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Onde:
#
# * hcdc - homem com doença cardíaca;
# * mcdc - mulher com doença cardíaca;
# * hsdc - homem sem doença cardíaca; e,
# * msdc - mulher sem doença cardíaca.

# %% [markdown]
# ####Q3. Que correlações podemos extrair deste *dataframe*?
#
# Podemos também plotar um gráfico para avaliar a dispersão das variáveis `age` e `chol` para buscar entender a correlação entre o avanço da idade e o crescimento das taxas de colesterol:

# %%
#Plotar o gráfico de dispersão para as variáveis `age` e `chol`

ig, ax = plt.subplots(figsize=(12,8))

ax.set_xlim(left=30,right=80)
sns.regplot('age', 'chol', scatter_kws={"s": 20},
            line_kws={"color": "red"}, data=df, ax=ax);

# %% [markdown]
# É interessante notar que podemos experimentar uma série de correlações, mas sempre devemos ter em mente qual o tipo de informação queremos obter. Por isso, nem sempre um gráfico de dispersão poderá nos atender, o que nos faz atentar para a possibilidade de analisar nossas informações com outros tipos de visualizações, como o histograma, por exemplo:

# %%
#plotar um histograma para o colesterol sérico
fig, ax = plt.subplots()
df.chol.hist(ax=ax)
ax.set_xlabel('Colesterol')
plt.show()

# %% [markdown]
# Ou, um gráfico em pizza:

# %%
#plotar um gráfico de pizza para `restecg`
# extrair as ocorrências para um dicionário
restecg_classificacao = dict(df.restecg.value_counts())

# preparar dados para o pie chart
labels = restecg_classificacao.keys()
sizes = restecg_classificacao.values()
explode = (0, 0, 0)

# plotar o gráfico de pizza
fig, ax = plt.subplots(figsize=(6,6))

ax.pie(sizes, labels=labels, explode=explode, shadow=False)
ax.set_title("Eletrocardiografia de Repouso")

plt.tight_layout()

# %% [markdown]
# Observe como a taxa de colesterol sérico entre 200 e 300 mg/dl tem um representação visual mais considerável no histograma. Observe também como, para a eletrocardiografia de repouso, há, aproximadamente, 49% de casos de hipertrofia ventricular esquerda provável ou definitiva (pelos critérios de Romhilt-Estes) contra 50% de casos normais.

# %% [markdown]
# ####Q4. Quantos dados ausentes nosso *dataframe* apresenta?
#
# Estes resultados são muito interessantes e abrangem todas linhas disponiveis, mas, como sabemos, nosso *dataframe* pode não ter todos os dados preenchidos, por isso vamos avaliar qual sua real situação no que se relaciona a dados ausentes:

# %%
#Verificação de dados ausentes
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# num          0
# condicoes    0
# dtype: int64

# %% [markdown]
# Impressionante! Nosso *dataframe* está completo com todas as informações! Esta conclusão é essencial já que vamos correlacionar os dados entre dois *dataframes*. Mas, antes, vamos ver como está a correlação entre os valores deste mesmo *dataframe*:

# %%
#Plotar um *heatmap* com as correlações
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, ax=ax, cmap='coolwarm');
plt.tight_layout()

# %% [markdown]
# O heatmap é um gráfico muito útil para identificar padrões, principalmente quando temos muitas variáveis no gráfico e que não apresenta restrição quanto ao tipo de variável, seja quantitativa ou qualitativa. No presente caso, podemos ver como a frequência cardíaca máxima (`thalach`) é bem demarcada pela relação "fria" no mapa, provavelmente por ter um valor numérico discrepante dos demais e também pela tendencia do mapa se "aquecer" no canto inferior direito do mapa, o que pode indicar uma relação de similaridade entre as variáveis, os quais, se analisados mais profundamente, podem trazer informações relevantes.

# %% [markdown]
# ###dataset_brasil:
#
# Vamos checar então a qualidade do nosso outro *dataframe*, o dataset_brasil e, para isso, vamos verificar primeiro seu volume de informações:

# %%
#tamanho do dataframe
print("Quantidade de linhas: ", df_brasil.shape[0])
print("Quantidade de colunas: ", df_brasil.shape[1])
# Out:
# Quantidade de linhas:  14
# Quantidade de colunas:  2

# %% [markdown]
# Vamos apenas visualizar as 5 primeiras entradas para ver como ele se comporta:

# %%
#Visualização das 5 primeiras entradas
df_brasil.head()
# Out:
#     ano  mortes_doencas_cardio
# 0  2017                383.961
# 1  2016                362.091
# 2  2015                349.584
# 3  2014                340.284
# 4  2013                339.672

# %% [markdown]
# Muito bem! vamos agora avaliar qual sua real situação no que se relaciona a dados ausentes:

# %% [markdown]
# ####Q1. Quantos dados ausentes nosso *dataframe* apresenta?

# %%
#Descrição estatística do dataframe
df_brasil.isnull().sum()
# Out:
# ano                      0
# mortes_doencas_cardio    0
# dtype: int64

# %% [markdown]
# ####Q2. Podemos avaliar a qualidade do *dataframe* através de um gráfico?

# %% [markdown]
# Como este *dataframe* apresenta todos os dados e tem poucas entradas, podemos agilizar sua análise por meio da visualização gráfica. Vamos plotar então um gráfico de linha para ver como ele se comporta:

# %%
#Impressão do gráfico de linha para dataset_brasil
fig, ax = plt.subplots(figsize=(12,8))
df_brasil.plot('ano', 'mortes_doencas_cardio', ax=ax)
ax.set_title("Mortes no Brasil")
ax.set_xlabel('Ano')
ax.set_ylabel("Mortes (mil)")
plt.tight_layout()

# %% [markdown]
# Note como, ao longo dos anos, a taxa de mortes vem aumentando no Brasil.

# %% [markdown]
# ## **Análise Da Correlação entre os *datasets***

# %% [markdown]
# Como os *dataframes* vêm de fontes diferentes e correspondem a países difierentes não existe uma correlação direta entre os mesmos, até mesmo não seria coerente efetuar alguma análise gráfica em conjunto. Entretanto, se observarmos o gráfico de dispersão plotado para o `dataset_uci`, vemos uma evolução da probabilidade de desenvolvimento de doenças cardíacas com o aumento do colesterol ao longo dos anos de vida. Posto isto, aplicando esta constatação no cenário brasileiro, podemos correlacionar o envelhecimento da população brasileira com o aumento do número de mortes por doenças cardíacas, bem como, provavelmente, o abuso de estilos de vida não saudáveis pelos brasileiros. Como podemos ver no site do [Ministério da Saúde](https://www.saude.gov.br/noticias/agencia-saude/45612-brasileiros-atingem-maior-indice-de-obesidade-nos-ultimos-treze-anos), o Brasil tem registrado um aumento na obesidade de sua população nos últimos anos, o que está intrinsecamente relacionado ao aumento de mortes por doenças cardíacas.

# %% [markdown]
# ## **Conclusões**

# %% [markdown]
# Esta análise teve como objetivo principal apresentar uma abordagem exploratória de dados relacionados a doenças cardíacas, descrevendo as ferramentas que podemos adotar para sua verificação. Espera-se assim fomentar a curiosidade sobre a ciência de dados.
